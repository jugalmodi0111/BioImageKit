# %%
import numpy as np, matplotlib.pyplot as plt
from skimage import data, registration
ref = data.camera(); mov = np.roll(ref, 3, axis=1)
shift, error, diff = registration.phase_cross_correlation(ref, mov, upsample_factor=10)
print('Estimated shift:', shift)
